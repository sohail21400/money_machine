# %%
import backtrader as bt
import datetime as dt
import import_ipynb
from Strategies.BuyHold import BuyHold
from Strategies.GoldenCross import GoldenCross

# %%
# initialize the Cerebro engine
cerebro = bt.Cerebro()
cerebro.broker.set_cash(10000)

data = bt.feeds.YahooFinanceCSVData(
    dataname="RELIANCE.NS-2022-08-25-to-2022-10-23.csv",
    reverse=False,)

cerebro.adddata(data)

# %%
print(f"Starting Portfolio Value: {cerebro.broker.getvalue():.2f}")
# Out:
# Starting Portfolio Value: 10000.00

# %%
cerebro.addstrategy(GoldenCross)
cerebro.run()
# Out:
# Buy 3 shares of SPY at 2623.45
# Sell 3 shares of SPY at 2594.5
# Buy 3 shares of SPY at 2569.0
# Sell 3 shares of SPY at 2579.55
# Buy 3 shares of SPY at 2579.35
# Sell 3 shares of SPY at 2600.5
# Buy 3 shares of SPY at 2527.1
# Sell 3 shares of SPY at 2519.5
# Buy 4 shares of SPY at 2370.25
# Sell 4 shares of SPY at 2394.85
# Buy 4 shares of SPY at 2389.95
# Sell 4 shares of SPY at 2360.5

# %%
cerebro.plot()
# Out:
# <img src="data:image/png;base64,..." width="966">
# [[<Figure size 640x480 with 5 Axes>]]
