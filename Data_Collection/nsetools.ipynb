# %%
from nsetools import Nse
import pandas as pd, numpy as np

# %%
nse = Nse()
q = nse.get_quote('INFY')
q
# Out:
# {'pricebandupper': 1650.95,
#  'symbol': 'INFY',
#  'applicableMargin': 14.52,
#  'bcEndDate': None,
#  'totalSellQuantity': None,
#  'adhocMargin': None,
#  'companyName': 'Infosys Limited',
#  'marketType': 'N',
#  'exDate': '27-OCT-22',
#  'bcStartDate': None,
#  'css_status_desc': 'Listed',
#  'dayHigh': 1506.0,
#  'basePrice': 1500.9,
#  'securityVar': 11.02,
#  'pricebandlower': 1350.85,
#  'sellQuantity5': None,
#  'sellQuantity4': None,
#  'sellQuantity3': None,
#  'cm_adj_high_dt': '17-JAN-22',
#  'sellQuantity2': None,
#  'dayLow': 1491.35,
#  'sellQuantity1': None,
#  'quantityTraded': 2491635.0,
#  'pChange': '-0.02',
#  'totalTradedValue': 53911.88,
#  'deliveryToTradedQuantity': 61.46,
#  'totalBuyQuantity': 2620.0,
#  'averagePrice': 1499.85,
#  'indexVar': None,
#  'cm_ffm': 549441.3,
#  'purpose': 'INTERIM DIVIDEND - RS 16.50 PER SHARE',
#  'buyPrice2': None,
#  'secDate': '21-Oct-2022 15:00:00',
#  'buyPrice1': 1500.5,
#  'high52': 1953.9,
# ...

# %%
pd.Series(nse.get_stock_codes())
# Out:
# SYMBOL                                 NAME OF COMPANY
# 20MICRONS                           20 Microns Limited
# 21STCENMGM    21st Century Management Services Limited
# 3IINFOLTD                          3i Infotech Limited
# 3MINDIA                               3M India Limited
#                                 ...
# ZOTA                          Zota Health Care LImited
# ZUARI                     Zuari Agro Chemicals Limited
# ZUARIIND                      ZUARI INDUSTRIES LIMITED
# ZYDUSLIFE                   Zydus Lifesciences Limited
# ZYDUSWELL                       Zydus Wellness Limited
# Length: 1826, dtype: object

# %%
pd.Series(nse.get_stock_codes())
# Out:
# SYMBOL                                 NAME OF COMPANY
# 20MICRONS                           20 Microns Limited
# 21STCENMGM    21st Century Management Services Limited
# 3IINFOLTD                          3i Infotech Limited
# 3MINDIA                               3M India Limited
#                                 ...
# ZOTA                          Zota Health Care LImited
# ZUARI                     Zuari Agro Chemicals Limited
# ZUARIIND                      ZUARI INDUSTRIES LIMITED
# ZYDUSLIFE                   Zydus Lifesciences Limited
# ZYDUSWELL                       Zydus Wellness Limited
# Length: 1826, dtype: object

# %%
pd.DataFrame(nse.get_index_list())
# Out:
#                     0
# 0   NIFTY 50 Pre Open
# 1            NIFTY 50
# 2       NIFTY NEXT 50
# 3     NIFTY100 LIQ 15
# 4          NIFTY BANK
# 5           INDIA VIX
# 6           NIFTY 100
# 7           NIFTY 500
# 8    NIFTY MIDCAP 100
# 9     NIFTY MIDCAP 50
# 10        NIFTY INFRA
# 11       NIFTY REALTY
# 12       NIFTY ENERGY
# 13         NIFTY FMCG
# 14          NIFTY MNC
# 15       NIFTY PHARMA
# 16          NIFTY PSE
# 17     NIFTY PSU BANK
# 18  NIFTY SERV SECTOR
# 19           NIFTY IT
# 20   NIFTY SMLCAP 100
# 21          NIFTY 200
# 22         NIFTY AUTO
# 23        NIFTY MEDIA
# 24        NIFTY METAL
# 25  NIFTY DIV OPPS 50
# 26  NIFTY COMMODITIES
# 27  NIFTY CONSUMPTION
# 28         NIFTY CPSE
# 29  NIFTY FIN SERVICE
# 30  NIFTY GROWSECT 15
# 31   NIFTY50 VALUE 20
# 32  NIFTY50 TR 2X LEV
# 33  NIFTY50 PR 2X LEV
# 34  NIFTY50 TR 1X INV
# 35  NIFTY50 PR 1X INV
# 36     NIFTY ALPHA 50
# 37    NIFTY50 EQL WGT
# 38   NIFTY100 EQL WGT
# 39  NIFTY100 LOWVOL30
# ...

# %%
# advances and declines in the NSE indices
pd.DataFrame(nse.get_advances_declines())
# Out:
#                 indice  advances  declines  unchanged
# 0             NIFTY 50      21.0      29.0        0.0
# 1        NIFTY NEXT 50       9.0      41.0        0.0
# 2             NIFTY IT       2.0       8.0        0.0
# 3           NIFTY BANK       9.0       3.0        0.0
# 4      NIFTY MIDCAP 50      16.0      32.0        2.0
# ..                 ...       ...       ...        ...
# 72   NIFTY MICROCAP250      62.0     182.0        6.0
# 73   NIFTY IND DIGITAL       8.0      21.0        1.0
# 74        NIFTY100 ESG      26.0      56.0        0.0
# 75   NIFTY M150 QLTY50      11.0      38.0        1.0
# 76  CNX NIFTY Pre Open      36.0       9.0        5.0
#
# [77 rows x 4 columns]

# %%
nse.get_index_quote('NIFTY 50')
# Out:
# {'name': 'NIFTY 50',
#  'lastPrice': 17576.3,
#  'change': 12.35,
#  'pChange': 0.07,
#  'imgFileName': 'NIFTY_50_open.png'}

# %%
pd.DataFrame(nse.get_top_gainers('NIFTY 50'))
# Out:
#        symbol series  openPrice  highPrice  lowPrice       ltp  previousPrice  \
# 0    AXISBANK     EQ     860.10     906.00    855.85    904.00         825.85
# 1   ICICIBANK     EQ     888.00     910.00    885.70    909.80         888.65
# 2   KOTAKBANK     EQ    1870.00    1925.00   1866.30   1905.00        1863.55
# 3     SBILIFE     EQ    1228.45    1250.25   1227.00   1247.60        1222.95
# 4  HINDUNILVR     EQ    2606.00    2666.75   2606.00   2652.60        2600.90
# 5  APOLLOHOSP     EQ    4344.15    4430.00   4322.70   4389.90        4322.50
# 6       TITAN     EQ    2650.00    2679.65   2640.05   2670.65        2631.50
# 7        ONGC     EQ     129.35     133.40    128.75    131.45         129.60
# 8   NESTLEIND     EQ   20061.10   20350.00  19982.50  20330.15       20061.10
# 9        SBIN     EQ     557.25     565.80    557.25    561.65         555.40
#
#    netPrice  tradedQuantity  turnoverInLakhs lastCorpAnnouncementDate  \
# ...

# %%
preopen_nifty = pd.DataFrame(nse.get_preopen_nifty())
preopen_nifty
# Out:
#         symbol series          xDt  \
# 0     AXISBANK     EQ         None
# 1          ITC     EQ         None
# 2    POWERGRID     EQ  19-Aug-2022
# 3   BHARTIARTL     EQ  01-Aug-2022
# 4   TATAMOTORS     EQ         None
# 5         ONGC     EQ  18-Aug-2022
# 6          UPL     EQ  27-Jul-2022
# 7    ICICIBANK     EQ  08-Aug-2022
# 8    TATASTEEL     EQ  28-Jul-2022
# 9         INFY     EQ         None
# 10  ASIANPAINT     EQ         None
# 11  BAJFINANCE     EQ         None
# 12       TITAN     EQ         None
# 13    ADANIENT     EQ         None
# 14  INDUSINDBK     EQ  11-Aug-2022
# 15    HINDALCO     EQ  11-Aug-2022
# 16  ADANIPORTS     EQ         None
# 17    HDFCLIFE     EQ         None
# 18  APOLLOHOSP     EQ  18-Aug-2022
# 19     HCLTECH     EQ  19-Oct-2022
# 20        BPCL     EQ  19-Aug-2022
# 21          LT     EQ         None
# 22     SBILIFE     EQ         None
# 23        HDFC     EQ         None
# 24    DIVISLAB     EQ  11-Aug-2022
# ...
